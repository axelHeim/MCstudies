# %%
import matplotlib.pyplot as plt
import uproot
import numpy as np
import pandas as pd

# %%
nfs_path = "/nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/"

# %%
fileY4S = uproot.open(nfs_path + "merged_DXtagDstl.root:variables")

# %%
df_Y4S = fileY4S.arrays(library="pd")

# %%
fileY4S.keys()
# Out:
# ['__experiment__',
#  '__run__',
#  '__event__',
#  '__candidate__',
#  '__ncandidates__',
#  '__weight__',
#  'm2RecoilSignalSide',
#  'foxWolframR2_maskedNaN',
#  'foxWolframR2',
#  'extraInfo__boFEIProbabilityRank__bc',
#  'nTracks',
#  'Up4S_isSig',
#  'BeamE',
#  'BeamPx',
#  'BeamPy',
#  'BeamPz',
#  'BeamcmsE',
#  'BeamcmsPx',
#  'BeamcmsPy',
#  'BeamcmsPz',
#  'genUp4S_PDG_0',
#  'genUp4S_charge_0',
#  'genUp4S_mdstIndex_0',
#  'genUp4S_genParticleID_0',
#  'genUp4S_E_0',
#  'genUp4S_Px_0',
#  'genUp4S_Py_0',
#  'genUp4S_Pz_0',
#  'genUp4S_P_0',
#  'genUp4S_cmE_0',
#  'genUp4S_cmPx_0',
#  'genUp4S_cmPy_0',
#  'genUp4S_cmPz_0',
#  'genUp4S_cmP_0',
#  'genUp4S_uniqParID_0',
#  'genUp4S_PDG_0_0',
#  'genUp4S_mdstIndex_0_0',
#  'genUp4S_genParticleID_0_0',
#  'genUp4S_uniqParID_0_0',
#  'genUp4S_PDG_0_0_0',
#  'genUp4S_mdstIndex_0_0_0',
#  'genUp4S_genParticleID_0_0_0',
#  'genUp4S_uniqParID_0_0_0',
#  'genUp4S_PDG_0_0_1',
#  'genUp4S_mdstIndex_0_0_1',
#  'genUp4S_genParticleID_0_0_1',
#  'genUp4S_uniqParID_0_0_1',
#  'genUp4S_PDG_0_1',
#  'genUp4S_mdstIndex_0_1',
#  'genUp4S_genParticleID_0_1',
#  'genUp4S_uniqParID_0_1',
#  'genUp4S_PDG_0_2',
#  'genUp4S_mdstIndex_0_2',
#  'genUp4S_genParticleID_0_2',
#  'genUp4S_uniqParID_0_2',
#  'genUp4S_PDG_1',
#  'genUp4S_charge_1',
#  'genUp4S_mdstIndex_1',
#  'genUp4S_genParticleID_1',
#  'genUp4S_E_1',
#  'genUp4S_Px_1',
#  'genUp4S_Py_1',
#  'genUp4S_Pz_1',
#  'genUp4S_P_1',
#  'genUp4S_cmE_1',
#  'genUp4S_cmPx_1',
#  'genUp4S_cmPy_1',
#  'genUp4S_cmPz_1',
#  'genUp4S_cmP_1',
#  'genUp4S_uniqParID_1',
#  'genUp4S_PDG_1_0',
#  'genUp4S_mdstIndex_1_0',
#  'genUp4S_genParticleID_1_0',
#  'genUp4S_uniqParID_1_0',
#  'genUp4S_PDG_1_0_0',
#  'genUp4S_mdstIndex_1_0_0',
#  'genUp4S_genParticleID_1_0_0',
#  'genUp4S_uniqParID_1_0_0',
#  'genUp4S_PDG_1_0_1',
#  'genUp4S_mdstIndex_1_0_1',
#  'genUp4S_genParticleID_1_0_1',
#  'genUp4S_uniqParID_1_0_1',
#  'genUp4S_PDG_1_1',
#  'genUp4S_mdstIndex_1_1',
#  'genUp4S_genParticleID_1_1',
#  'genUp4S_uniqParID_1_1',
#  'genUp4S_PDG_1_2',
#  'genUp4S_mdstIndex_1_2',
#  'genUp4S_genParticleID_1_2',
#  'genUp4S_uniqParID_1_2',
#  'Btag_uniqParID',
#  'dau0_M',
#  'dau0_chiProb',
#  'dau0_cmp',
#  'dau0_cmE',
#  'dau0_cmpx',
#  'dau0_cmpy',
#  'dau0_cmpz',
#  'dau0_cmpt',
#  'dau0_p',
#  'dau0_E',
#  'dau0_px',
#  'dau0_py',
#  'dau0_pz',
#  'dau0_pt',
#  'dau0_mcp',
#  'dau0_mcpt',
#  'dau0_dau1_charge',
#  'dau0_dau0_motherP',
#  'dau0_dau0_motherE',
#  'dau0_dau0_motherPx',
#  'dau0_dau0_motherPy',
#  'dau0_dau0_motherPz',
#  'dau0_dau0_mothercmsP',
#  'dau0_dau0_mothercmsE',
#  'dau0_dau0_mothercmsPx',
#  'dau0_dau0_mothercmsPy',
#  'dau0_dau0_mothercmsPz',
#  'dau0_dau0_motherPDG',
#  'dau0_dau0_grandmotherP',
#  'dau0_dau0_grandmotherE',
#  'dau0_dau0_grandmotherPx',
#  'dau0_dau0_grandmotherPy',
#  'dau0_dau0_grandmotherPz',
#  'dau0_dau0_grandmotherPDG',
#  'dau0_mccmp',
#  'dau0_mccmpt',
#  'dau0_decmode',
#  'dau0_sigProb',
#  'dau0_dau0_decmode',
#  'dau0_dau0_sigProb',
#  'dau0_dau0_charge',
#  'dau0_dau0_M',
#  'dau0_dau0_DeltaM',
#  'dau0_dau0_E',
#  'dau0_dau0_px',
#  'dau0_dau0_py',
#  'dau0_dau0_pz',
#  'dau0_dau0_PDG',
#  'dau0_dau0_isSignal',
#  'dau0_dau0_isSignalAcceptMissingGamma',
#  'dau0_dau1_M',
#  'dau0_dau1_E',
#  'dau0_dau1_px',
#  'dau0_dau1_py',
#  'dau0_dau1_pz',
#  'dau0_dau1_nDaughters',
#  'dau0_dau1_dau0_PDG',
#  'dau0_dau1_dau1_PDG',
#  'dau0_dau1_dau2_PDG',
#  'dau0_dau1_dau3_PDG',
#  'dau0_dau2_p',
#  'dau0_deltaE',
#  'dau0_Mbc',
#  'dau0_FEIRank',
#  'dau0_isSignal',
#  'dau0_R2',
#  'dau0_cosTBTO',
#  'dau0_cosThetaBetweenParticleAndNominalB',
#  'dau0_PDG',
#  'dau0_motherPDG',
#  'Bsig_uniqParID',
#  'dau1_Nelectrons',
#  'dau1_Nmuons',
#  'dau1_Npip',
#  'dau1_NKp',
#  'dau1_M',
#  'dau1_cmp',
#  'dau1_cmE',
#  'dau1_cmpx',
#  'dau1_cmpy',
#  'dau1_cmpz',
#  'dau1_cmpt',
#  'dau1_theta',
#  'dau1_p',
#  'dau1_E',
#  'dau1_px',
#  'dau1_py',
#  'dau1_pz',
#  'dau1_pt',
#  'dau1_mcp',
#  'dau1_mcpt',
#  'dau1_mccmE',
#  'dau1_mccmp',
#  'dau1_mccmpx',
#  'dau1_mccmpy',
#  'dau1_mccmpz',
#  'dau1_mccmpt',
#  'dau1_cosThetaBetweenParticleAndNominalB',
#  'dau1_isSignal',
#  'dau1_mcPDG',
#  'dau1_dau0_mcPDG',
#  'dau1_dau1_mcPDG',
#  'dau1_dau0_mothermdstIndex',
#  'dau1_dau1_mothermdstIndex',
#  'dau1_mdstIndex',
#  'dau1_motherPDG',
#  'lep_mdstIndex',
#  'lep_PDG',
#  'lep_theta',
#  'lep_clusterEP',
#  'lep_clusterE',
#  'lep_eID',
#  'lep_muID',
#  'lep_clusterE9E21',
#  'lep_absdz',
#  'lep_absd0',
#  'lep_klmLayers',
#  'lep_MatchedKLMClusters',
#  'lep_M',
#  'lep_chiProb',
#  'lep_cmE',
#  'lep_cmp',
#  'lep_cmpx',
#  'lep_cmpy',
#  'lep_cmpz',
#  'lep_cmpt',
#  'lep_E',
#  'lep_p',
#  'lep_px',
#  'lep_py',
#  'lep_pz',
#  'lep_pt',
#  'lep_mcp',
#  'lep_mcpt',
#  'lep_mccmp',
#  'lep_mccmpt',
#  'lep_mcPDG',
#  'lep_genParticleID',
#  'lep_motherPDG',
#  'lep_gmotherPDG',
#  'lep_genmotherID',
#  'lep_mothermdstIndex',
#  'lep_uniqParID',
#  'lepMother_uniqParID',
#  'D_dau0_genGmothID',
#  'D_dau0_motherPDG',
#  'D_dau0_gmotherPDG',
#  'D_dau0_mcPDG',
#  'D_dau1_genGmothID',
#  'D_dau1_motherPDG',
#  'D_dau1_gmotherPDG',
#  'D_dau1_mcPDG',
#  'D_dau2_genGmothID',
#  'D_dau2_motherPDG',
#  'D_dau2_gmotherPDG',
#  'D_dau2_mcPDG',
#  'D_dau3_genGmothID',
#  'D_dau3_motherPDG',
#  'D_dau3_gmotherPDG',
#  'D_dau3_mcPDG',
#  'D_dau4_genGmothID',
#  'D_dau4_motherPDG',
#  'D_dau4_gmotherPDG',
#  'D_dau4_mcPDG',
#  'slowPi_motherPDG',
#  'slowPi_mcPDG',
#  'Dst_genParticleID',
#  'D_nDaughters',
#  'D_M',
#  'D_p',
#  'D_pt',
#  'D_cmp',
#  'D_cmpt',
#  'D_isSignal',
#  'D_uniqParID',
#  'Dst_uniqParID',
#  'Dst_M',
#  'Dst_E',
#  'Dst_p',
#  'Dst_px',
#  'Dst_py',
#  'Dst_pz',
#  'Dst_pt',
#  'Dst_cmE',
#  'Dst_cmp',
#  'Dst_cmpx',
#  'Dst_cmpy',
#  'Dst_cmpz',
#  'Dst_cmpt',
#  'Dst_mccmE',
#  'Dst_mccmp',
#  'Dst_mccmpx',
#  'Dst_mccmpy',
#  'Dst_mccmpz',
#  'Dst_DeltaM',
#  'Dst_isSignal']

# %%
names = ["gammas","electrons","pions","kaons","muons"]
dfs = []
for name in names:
    filename=nfs_path + "merged_{}.root:variables".format(name)
    print(filename)
    tmpFileFSPs = uproot.open(filename)
    df_tmp = tmpFileFSPs.arrays(library="pd")
    dfs.append(df_tmp)
# Out:
# /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/merged_gammas.root:variables
# /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/merged_electrons.root:variables
# /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/merged_pions.root:variables
# /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/merged_kaons.root:variables
# /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/Dstlnu_skim/axheim_DstlnuSKIM_run1/merged_muons.root:variables

# %%
df_FSPs = pd.concat(dfs)

# %%
print(df_FSPs.shape[0])
# Out:
# 12556867

# %% [markdown]
# ### delete particles which occur more than ones based on uniqueParticleIdentifier

# %%
df_FSPs_noDuplis = df_FSPs.sort_values("basf2_used",ascending=False).drop_duplicates(subset=("__event__","uniqueParticleIdentifier"), keep='first')

# %%
print(df_FSPs_noDuplis.shape[0])
# Out:
# 8594615

# %% [markdown]
# ## save and load df after duplication of FSPs removal

# %%
df_FSPs_noDuplis.to_csv(nfs_path + "skimFSPs_df.csv")
df_Y4S.to_csv(nfs_path + "skimY4S_df.csv")

# %%
#df_FSPs_noDuplis = pd.read_csv(nfs_path + "skimFSPs_df.csv")
#df_Y4S = pd.read_csv(nfs_path + "skimY4S_df.csv")

# %% [markdown]
# ## check for number of events

# %%
df_Y4S["__event__"].nunique()
# Out:
# 11771

# %%
df_FSPs_noDuplis["__event__"].nunique()
# Out:
# 465660

# %%
df_FSPs_noDuplis["__event__"].value_counts()
# Out:
# 1485463    42
# 3507296    41
# 7748014    41
# 6026888    41
# 7171164    41
#            ..
# 3087076     4
# 340336      4
# 5840747     4
# 7372468     4
# 7169083     4
# Name: __event__, Length: 465660, dtype: int64

# %%
take_subset=False
if take_subset:
    df_sample = df_FSPs_noDuplis.sample(n=10000)
    df_FSPs=df_sample
else:
    df_FSPs=df_FSPs_noDuplis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-edd54969a7b9> in <module>
# ----> 1 take_subset==False
#       2 if take_subset:
#       3     df_sample = df_FSPs_noDuplis.sample(n=10000)
#       4     df_FSPs=df_sample
#       5 else:
#
# NameError: name 'take_subset' is not defined

# %%
def isBtoDstlnu(s):
    isDecay = 0
    
    if ((np.abs(s["lep_mcPDG"]) == 13.0) or (np.abs(s["lep_mcPDG"]) == 11.0)): # lepton is electron or muon
        if (np.abs(s["lep_motherPDG"]) == 511.0): # leptons mother is B
            if (np.abs(s["dau1_dau0_mcPDG"]) == 413.0): # daughter of B is D*+ 
                isDecay = 1
            
    return isDecay
df_Y4S['isBtoDstlnu'] = df_Y4S.apply(isBtoDstlnu, axis=1)

# %%
df_Y4S['isBtoDstlnu'].value_counts()
# Out:
# 0    6110
# 1    5661
# Name: isBtoDstlnu, dtype: int64

# %%
# Out:
#  300553.0    3553
#  413.0       2894
# -413.0       2855
#  511.0        178
# -511.0        175
# -431.0          1
# -20413.0        1
#  443.0          1
#  423.0          1
#  20433.0        1
# Name: dau1_dau0_mcPDG, dtype: int64

# %%
df_FSPs_noDuplis[df_FSPs_noDuplis["__event__"] == 3507296][['mcPDG','mcMother0_uniqParID', 'genMothPDG_0', 'genMotherID_0',
'mcMother1_uniqParID', 'genMothPDG_1', 'genMotherID_1',
'mcMother2_uniqParID', 'genMothPDG_2', 'genMotherID_2',
'mcMother3_uniqParID', 'genMothPDG_3', 'genMotherID_3',
'mcMother4_uniqParID', 'genMothPDG_4', 'genMotherID_4',
'mcMother5_uniqParID', 'genMothPDG_5', 'genMotherID_5',
'mcMother6_uniqParID', 'genMothPDG_6', 'genMotherID_6',
'mcMother7_uniqParID', 'genMothPDG_7', 'genMotherID_7',
'mcMother8_uniqParID', 'genMothPDG_8', 'genMotherID_8',
'mcMother9_uniqParID', 'genMothPDG_9', 'genMotherID_9']
]
# Out:
#          mcPDG  mcMother0_uniqParID  genMothPDG_0  genMotherID_0  \
# 1062050  321.0           83886095.0         411.0           15.0
# 1062051  -11.0           83886140.0          22.0           60.0
# 1062052  211.0           83886095.0         411.0           15.0
# 1062053  211.0           83886101.0         310.0           21.0
# 1062054  321.0           83886106.0        -421.0           26.0
# 1062055  -13.0           83886082.0         511.0            2.0
# 1062056 -321.0           83886081.0        -511.0            1.0
# 1062057 -321.0           83886095.0         411.0           15.0
# 1062058 -211.0           83886101.0         310.0           21.0
# 1062059 -211.0           83886106.0        -421.0           26.0
# 1416688   22.0           83886084.0         111.0            4.0
# 1416679   22.0           83886123.0        -211.0           43.0
# 1416680   22.0           83886129.0         111.0           49.0
# 1416681   22.0           83886096.0         111.0           16.0
# 1416682    NaN                  NaN           0.0            0.0
# 1416683   22.0           83886119.0         111.0           39.0
# 1416684   22.0           83886129.0         111.0           49.0
# 1416685   22.0           83886121.0         111.0           41.0
# 1416686  -13.0           83886122.0         321.0           42.0
# 1416687    NaN                  NaN           0.0            0.0
# 1416678    NaN                  NaN           0.0            0.0
# 1416677   22.0           83886123.0        -211.0           43.0
# 1416676   22.0           83886123.0        -211.0           43.0
# 1416675   22.0           83886119.0         111.0           39.0
# 1416660   22.0           83886087.0         111.0            7.0
# 1416661 -211.0           83886085.0        -321.0            5.0
# 1416687                  NaN           0.0            0.0
# 1416678                  NaN           0.0            0.0
# 1416677                  NaN           0.0            0.0
# 1416676                  NaN           0.0            0.0
# 1416675                  NaN           0.0            0.0
# 1416660                  NaN           0.0            0.0
# 1416661                  NaN           0.0            0.0
# 1416662                  NaN           0.0            0.0
# 1416663                  NaN           0.0            0.0
# 1416664                  NaN           0.0            0.0
# 1416665                  NaN           0.0            0.0
# 1416666                  NaN           0.0            0.0
# 1416667                  NaN           0.0            0.0
# 1416668                  NaN           0.0            0.0
# 1416669                  NaN           0.0            0.0
# 1416670                  NaN           0.0            0.0
# 1416671                  NaN           0.0            0.0
# 1416672                  NaN           0.0            0.0
# 1416673                  NaN           0.0            0.0
# 1416674                  NaN           0.0            0.0
# 1164289                  NaN           0.0            0.0
# 1164290                  NaN           0.0            0.0
#
# [41 rows x 31 columns]

# %%
df_FSPs_noDuplis.keys()
# Out:
# Index(['__experiment__', '__run__', '__event__', '__candidate__',
#        '__ncandidates__', '__weight__', 'basf2_X', 'basf2_used', 'basf2_Bsig',
#        'isSignal', 'uniqueParticleIdentifier', 'mcErrors', 'mcPDG',
#        'genMotherID', 'genMotherP', 'genMotherPDG', 'px', 'py', 'pz', 'pt',
#        'p', 'E', 'kaonID', 'pionID', 'genMothPDG_0', 'genMothPDG_1',
#        'genMothPDG_2', 'genMothPDG_3', 'genMothPDG_4', 'genMothPDG_5',
#        'genMothPDG_6', 'genMothPDG_7', 'genMothPDG_8', 'genMothPDG_9',
#        'genMotherID_0', 'genMotherID_1', 'genMotherID_2', 'genMotherID_3',
#        'genMotherID_4', 'genMotherID_5', 'genMotherID_6', 'genMotherID_7',
#        'genMotherID_8', 'genMotherID_9', 'mcMother0_uniqParID',
#        'mcMother1_uniqParID', 'mcMother2_uniqParID', 'mcMother3_uniqParID',
#        'mcMother4_uniqParID', 'mcMother5_uniqParID', 'mcMother6_uniqParID',
#        'mcMother7_uniqParID', 'mcMother8_uniqParID', 'mcMother9_uniqParID',
#        'PDG'],
#       dtype='object')

# %%
for i in range(10):
    print("'mcMother{}_uniqParID',".format(i),"'genMothPDG_{}',".format(i),"'genMotherID_{}',".format(i))
# Out:
# 'mcMother0_uniqParID', 'genMothPDG_0', 'genMotherID_0',
# 'mcMother1_uniqParID', 'genMothPDG_1', 'genMotherID_1',
# 'mcMother2_uniqParID', 'genMothPDG_2', 'genMotherID_2',
# 'mcMother3_uniqParID', 'genMothPDG_3', 'genMotherID_3',
# 'mcMother4_uniqParID', 'genMothPDG_4', 'genMotherID_4',
# 'mcMother5_uniqParID', 'genMothPDG_5', 'genMotherID_5',
# 'mcMother6_uniqParID', 'genMothPDG_6', 'genMotherID_6',
# 'mcMother7_uniqParID', 'genMothPDG_7', 'genMotherID_7',
# 'mcMother8_uniqParID', 'genMothPDG_8', 'genMotherID_8',
# 'mcMother9_uniqParID', 'genMothPDG_9', 'genMotherID_9',
