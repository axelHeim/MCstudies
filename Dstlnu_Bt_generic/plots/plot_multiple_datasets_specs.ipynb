# %%
import pandas as pd
from pathlib import Path

import math

import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '/afs/desy.de/user/a/axelheim/private/run_BaumBauenNotebooks')

from datetime import datetime

from tb_to_csv import tabulate_metrics
from plot_fcts import curve_plot, multi_metric_bar_plot, curve_plot_accuracies


# if true: longest run will be plotted, if false: the most recent one will be plotted
take_longestRun = False

# %%
#data_names = ["Dstlnu_Hc_corr_BsigX_separation_dataRun1/axheim_data2_MC14_100kEvts"]

#specs = ["1024_0.001_32_0.3_8"] #"512_0.001_128_0.3_8"

# %%
data_names = ["Dstlnu_SHR_BsX/TestSmall_SHR_dataSteering_run1"]

specs = ["512_0.001_128_0.3_4","512_0.001_64_0.3_8","512_0.001_128_0.3_6"]#["1024_0.001_32_0.3_8","512_0.001_128_0.3_8"] #"512_0.001_128_0.3_8"

# %%
data_names = ["Dstlnu_SHR_BsX_p50cut/SHR_dataSteering_run1"]

specs = ["512_0.001_64_0.3_4",
"256_0.001_128_0.3_6"]

# %%
data_names = ["Dstlnu_SHR_BsX_p100cut/SHR_dataSteering_run1"]

specs = ["512_0.001_64_0.3_4",
"256_0.001_128_0.3_6","1024_0.001_64_0.3_4",
"512_0.001_64_0.3_8",
"256_0.001_64_0.3_8",
"512_0.001_64_0.3_6",
"512_0.001_256_0.3_4"]

# %%
data_names = ["TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_allExtras",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_M",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_dr",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_dz",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_charge",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_clReg",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_E9E21",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_pID",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_kID",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_eID",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_muID",
"TMP_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_only4mom"]

specs = ["512_0.001_64_0.3_4"]

# %%
data_names = ["FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_allExtras",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_IDchargeM",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_chargeM",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_chargeIDs",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_chargePionID",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_only4mom",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_charge",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_M",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_charge",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_dr",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_dz",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_clReg",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_E9E21",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_pID",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_kID",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_eID",
"FULLCMrun_Dstlnu_SHR_BsX_Ablations/SHR_CMvars_run1/SUPA_no_muID"]

specs = ["512_0.001_64_0.3_4"]

# %%
data_names = ["NAHSA_creation1/NAHS_100kRun1/NAHSA_only4mom"]

specs = [
"256_0.001_64_0.2_2"]

# %%
data_names = ["NAHSA_creation1/NAHS_100kRun1/NAHSA_only4mom"]

specs = [
"512_0.001_64_0.2_4",
"512_0.001_64_0.2_2",
"256_0.001_64_0.2_2",
"512_0.001_64_0.2_4"]

# %%
data_names = ["NAHSA_creation1/NAHS_100kRun1/NAHSA_allExtras",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_charge",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_chargeIDs",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_chargeM",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_chargePionID",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_IDchargeM",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_charge",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_clReg",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_dr",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_dz",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_E9E21",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_eID",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_kID",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_M",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_muID",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_pID",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_only4mom",
"NAHSA_creation1/NAHS_100kRun1/NAHSA_no_proID"
             ]

specs = [
"256_0_64_0.2_2"]

# %%
data_names = ["NAHSA_creation1/NAHS_100kRun1/NAHSA_only4mom"]

specs = [
"512_0.001_64_0.2_4"]

# %%
data_names = ["NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_only4mom"]

specs = ["256_0_64_0.2_2",
"512_0_64_0.2_2",
"1024_0_64_0.2_2",
"256_0_64_0.2_4",
]

# %%
data_names = ["NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz_uncer",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_charge",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargeIDs",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargeM",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargePionID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_Hc_xyz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_Hc_xyz_uncertain",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_IDchargeM",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_charge",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_clReg",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_dr",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_dz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_E9E21",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_eID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_kID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_M",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_muID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_pID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_proID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_only4mom"]

specs = [
"256_0_64_0.2_4"
]

# %%
data_names = ["NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras"]

specs = [
"256_0_64_0.01_4",
"256_0_64_0.1_4",
"256_0_64_0.2_4",
"256_0_64_0.3_4",
"256_0_64_0.4_4",
"256_0_64_0.5_4",
"256_0_64_0.6_4",
"256_0_64_0.7_4"
]

# %%
data_names = ["NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz_uncer",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_charge",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargeIDs",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargeM",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_chargePionID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_Hc_xyz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_Hc_xyz_uncertain",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_IDchargeM",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_charge",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_clReg",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_dr",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_dz",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_E9E21",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_eID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_kID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_M",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_muID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_pID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_no_proID",
"NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_only4mom"]

specs = [
"256_0_64_0.1_4"
]

# %%
plotted_specs=[]
names = []
perfSA = []
SA_1F = []
SA_2F = []
SA_3F = []
SA_bad = []
max_acc = []
epochs_trained = []
for data_name in data_names:
    for spec in specs:
        plotname_extension = data_name + '_' + spec
        plotname_extension = plotname_extension.replace("/", "_")
        nfs_path = "/nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/"

        plot_path = "/afs/desy.de/user/a/axelheim/private/MC_studies/Dstlnu_Bt_generic/"
        
        print("data_name:",data_name)
        data_dir = Path((nfs_path + 'tb_logs/' + data_name + '/' + spec))
        #data_dir = ((nfs_path + 'tb_logs/' + data_name + '/' + spec))
        print("\n now processing:",data_dir)
        #if not data_dir.is_dir():
        #    print("dir not found in: ", data_dir, "\n skip dir")
        #    continue
        
        
        csv_dir = Path((nfs_path + 'tb_csv/' + data_name + '/' + spec))
        csv_dir.mkdir(parents=True, exist_ok=True)

        plot_path = Path((plot_path + 'plots/' + data_name + '/' + spec))
        plot_path.mkdir(parents=True, exist_ok=True)

        tb_metrics = tabulate_metrics(data_dir, csv_dir)

        
        # choosing the tb_log with the most epochs recorded
        epochs = []
        starttime = []
        for i in range(len(tb_metrics)):
            epochs.append(len(tb_metrics[i]))
            starttime.append(tb_metrics[i]["Time/secs"][0])
            print("len(tb_metrics[{}]):".format(i),len(tb_metrics[i]))
            print("start time of run:",datetime.fromtimestamp(tb_metrics[i]["Time/secs"][0]))
        most_epochs_idx = 0
        latestStart_idx = 0
        if len(tb_metrics) > 1:
            most_epochs_idx = epochs.index(max(epochs))
            latestStart_idx = starttime.index(max(starttime))
            #most_epochs_idx = epochs.index(min(epochs))
        
        print("most_epochs_idx:",most_epochs_idx)
        print("latestStart_idx:",latestStart_idx)
        print("len(tb_metrics):",len(tb_metrics))
        if len(tb_metrics) < 1:
            continue
        
        if take_longestRun == True:
            longest_run = tb_metrics[most_epochs_idx]
        else:
            longest_run = tb_metrics[latestStart_idx]
        
        epochs_trained.append(len(longest_run))
        # the actual plots
        # bar plot
        steps = math.ceil(len(longest_run)/10)
        steps = int(math.ceil(steps / 5.0)) * 5
        multi_metric_bar_plot(longest_run, plot_path, ('barplot_metrics_' + plotname_extension), data_type="Validation", step=steps, metric_type="SA", title=plotname_extension)
        
        
        # loss plot
        loss_tr = longest_run['Cross Entropy/Training']
        loss_val = longest_run['Cross Entropy/Validation']
        curve_plot(loss_tr, loss_val, plot_path, ('loss_comparison_' + plotname_extension), 'Cross_Entropy', ('Loss / ' + plotname_extension))

        # perfect SA plot
        pLCA_tr = longest_run['PerfectSA/Training']
        pLCA_val = longest_run['PerfectSA/Validation']
        curve_plot(pLCA_tr, pLCA_val, plot_path, ('perfectSA_comparison_' + plotname_extension), 'PerfectSA', ('PerfectSA / ' + plotname_extension))
        names.append(plotname_extension)
        
        
        
        
        # M_bc plot
        Mbc_tr = longest_run["Mbc Peak Fraction/Training"]
        Mbc_val = longest_run["Mbc Peak Fraction/Validation"]
        curve_plot(Mbc_tr, Mbc_val, plot_path, ('Mbc_comparison_' + plotname_extension), 'Mbc fraction', ('Mbc frac./ ' + plotname_extension))
        
        
        
        # plot accuracies
        acc_all = longest_run["Accuracy/Validation"]
        acc_bg = longest_run["AccClass0/Validation"]
    
        idxmax = acc_all.idxmax()

        max_acc.append(acc_all[idxmax])
        perfSA.append(pLCA_val[idxmax])
        SA_1F.append(longest_run["SA1F/Validation"][idxmax])
        SA_2F.append(longest_run["SA2F/Validation"][idxmax])
        SA_3F.append(longest_run["SA3F/Validation"][idxmax])
        SA_bad.append(longest_run["SAbad/Validation"][idxmax])
        
        
        # case BsXHc
        acc_X = longest_run["AccClass1/Validation"]
        acc_Bs = longest_run["AccClass2/Validation"]
        #acc_Hc = longest_run["AccClass3/Validation"]
        
        #data_name +="BsX"
        #print("data_name:",data_name)
        acc_Hc = None
        # case BsX
        #if data_name.find("BsX") != -1 and data_name.find("Hc") == -1:
        #    acc_Hc = None
            
        # case XHc
        #if data_name.find("XHc") != -1 and data_name.find("Bs") == -1:
        #    acc_Bs = None
        #    acc_Hc = longest_run["AccClass2/Validation"]  
            
        # case BsHc
        #if data_name.find("BsHc") != -1:
        #    acc_X = None
        #    acc_Hc = longest_run["AccClass1/Validation"]
            
        
                
        
        curve_plot_accuracies(plot_path, ('accuracies_comparison_' + plotname_extension), 'Accuracy/Validation',
                              ('Accuracies / ' + plotname_extension),
                             acc_all=acc_all, acc_bg=acc_bg, acc_X=acc_X, acc_Bs=acc_Bs, acc_Hc=acc_Hc)
        
        
        plotted_specs.append(data_name + '///' + spec)
        print("---------------------------- \n")
# Out:
# data_name: NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras
#
#  now processing: /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/tb_logs/NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras/256_0_64_0.1_4
# Converting run events.out.tfevents.1635497550.batchg003.desy.de.67354.0
#
# - Done
# Converting run events.out.tfevents.1635608575.batchg005.desy.de.181006.0
#
# - Done
# len(tb_metrics[0]): 121
# start time of run: 2021-10-29 10:53:20
# len(tb_metrics[1]): 121
# start time of run: 2021-10-30 17:45:04
# most_epochs_idx: 0
# latestStart_idx: 1
# len(tb_metrics): 2
# ----------------------------
#
# data_name: NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz
#
#  now processing: /nfs/dust/belle2/user/axelheim/MC_studies/Dstlnu_Bt_generic/tb_logs/NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras_xyz/256_0_64_0.1_4
# Converting run events.out.tfevents.1635608574.batchg003.desy.de.172893.0
#
# - Done
# len(tb_metrics[0]): 121
# start time of run: 2021-10-30 17:45:04
# ...

# %%
for i in range(len(names)):
    print("data&specs:", names[i])
    print("scored perfect SA:", round(100*perfSA[i],1),"%")
    print("scored max accuracy:", round(100*max_acc[i],1),"%")
    print("epochs trained:",epochs_trained[i],'\n')

# %%
names2 = [a[41:-15] for a in names]
names2

# %%
max_acc2 = [round(a*100,2) for a in max_acc]
perfSA2 = [round(a*100,2) for a in perfSA]
SA_1F2 = [round(a*100,2) for a in SA_1F]
SA_2F2 = [round(a*100,2) for a in SA_2F]
SA_3F2 = [round(a*100,2) for a in SA_3F]
SA_bad2 = [round(a*100,2) for a in SA_bad]

# %%
df = pd.DataFrame({"name":names2, "perfSA":perfSA2,"SA_1F":SA_1F2,"SA_2F":SA_2F2,"SA_3F":SA_3F2,"SA_bad":SA_bad2,"max_acc":max_acc2,"epochs":epochs_trained})

# %%
df.sort_values("max_acc", ascending=False)

# %%
for i in range(len(plotted_specs)):
    print(plotted_specs[i])
# Out:
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.01_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.1_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.2_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.3_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.4_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.5_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.6_4
# NAHSA_Gmodes_1/NAHS_allEvts_oneSub/NAHSA_allExtras///256_0_64_0.7_4

# %%
print("used time in hours:",round((longest_run["Time/secs"].iloc[-1]-longest_run["Time/secs"][0] )/(60*60),2))
# Out:
# used time in hours: 10.92

# %%
type(longest_run["Time/secs"])
# Out:
# pandas.core.series.Series

# %%
latestStart_idx
# Out:
# 0

# %%
tb_metrics[0]["Accuracy/Training"].max()
# Out:
# 0.617962121963501

# %%
tb_metrics[0]["Accuracy/Training"]
# Out:
# 0    0.612806
# 1    0.614600
# 2    0.617962
# Name: Accuracy/Training, dtype: float64

# %%
tb_metrics[0]["Accuracy/Validation"]
# Out:
# 0     0.606578
# 1     0.617705
# 2     0.625975
# 3     0.630454
# 4     0.642162
# 5     0.648447
# 6     0.659419
# 7     0.663658
# 8     0.670494
# 9     0.673533
# 10    0.668294
# 11    0.677343
# 12    0.671603
# 13    0.682033
# 14    0.686110
# 15    0.686944
# 16    0.689439
# 17    0.689972
# 18    0.684493
# 19    0.695156
# 20    0.710454
# Name: Accuracy/Validation, dtype: float64
